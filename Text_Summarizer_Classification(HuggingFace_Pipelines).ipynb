# %%
# !pip install transformers

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.6 MB/s eta 0:00:00
# ...

# %%
import transformers
from transformers import pipeline

pipe = pipeline("text-classification")
pipe("The sky is blue which looks absolutely magical")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998470544815063}]

# %%
# pipeline for text classification
pipe = pipeline("sentiment-analysis")
pipe(["This restaurent is awesome", "This restaurent is awful"])
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998663663864136},
#  {'label': 'NEGATIVE', 'score': 0.999752938747406}]

# %% [markdown]
# # Text Summarization
# - NLP technique to generate a concise summary of a longer text while preserving its main points.

# %%
text = """
Pros of AI:

Efficiency: AI can quickly generate large amounts of text, saving time and effort in content creation.
Variety: AI can produce content in different styles, tones, and languages, making it versatile for various purposes.
Cost Savings: It can reduce the need for hiring additional content creators or writers, which can lower labor costs.
Consistency: AI maintains a consistent tone and style, which is essential for branding and messaging consistency.
Availability: AI can work 24/7, providing content on-demand without human li

"""

# %%
summarizer = pipeline("summarization")
summarizer(text, min_length=5, max_length=30)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'summary_text': ' AI can quickly generate large amounts of text, saving time and effort in content creation . It can reduce the need for hiring additional content creators'}]
